# %% [markdown]
# <a href="https://colab.research.google.com/github/khoirul2003/PVCK_Ganjil_2025/blob/main/week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import math
from google.colab.patches import cv2_imshow
from PIL import Image as im

# %%
def convolution(image, krrnel):
  image_heidht, image_widhth = image.shape
  kernel_height, kernel_width = krrnel.shape

  pad_height = kernel_height // 2
  pad_width = kernel_width // 2

  paddes_image = np.pad(image, ((pad_height, pad_height), (pad_width, pad_width)), mode='constant')

  output_image = np.zeros((image_heidht, image_widhth))

  for y in range(image_heidht):
    for x in range(image_widhth):
      roi = paddes_image[y:y+kernel_height, x:x + kernel_width]
      output_image[y, x] = np.sum(roi * kernel)

  return output_image

# %%
image_path = '/contrnt/drive/MyDrive/Images/mandrill.tiff'
img = Image.open(image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3274912065.py in <cell line: 0>()
#       1 image_path = '/contrnt/drive/MyDrive/Images/mandrill.tiff'
# ----> 2 img = Image.open(image_path)
#
# NameError: name 'Image' is not defined
